# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df_us_2021=pd.read_csv("US_2021.csv")
df_ca_2021=pd.read_csv("CA_2021.csv")
df_gb_2021=pd.read_csv("GB_2021.csv")

# %%
df_us1_2021=df_us_2021.iloc[:,[1]]
df_ca1_2021=df_ca_2021.iloc[:,[1]]
df_gb1_2021=df_gb_2021.iloc[:,[1]]

# %%
#dropping null values
df_us1_2021.dropna(inplace = True)
df_ca1_2021.dropna(inplace = True)
df_gb1_2021.dropna(inplace = True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)

# %% [markdown]
# # Unique hashtags count 2021

# %%
import re
dict_us_21={}
hashtag_us_21=[]
for i in range(0, len(df_us1_2021)):
  k= df_us1_2021.at[i,"text"]
  ind = [i.start() for i in re.finditer("#", k)]
  for j in range(len(ind)):
    ind1=k[ind[j]:].find(" ")
    if(ind1==-1):
      word=k[ind[j]:]
    else:
      word=k[ind[j]:ind1]
    if(word not in dict_us_21):
      hashtag_us_21.append(word)
      dict_us_21[word]=1
print(hashtag_us_21)
print("number of unique hashtags in US 2021:" +str(len(hashtag_us_21)-1))
# Out:
# ['', '#', '#SuperBowl', '#S', '#TheWeeknd', '#SBGCBrotherhood.', '#sbgcbrotherhood', '#superspreader', '#SBGCBrotherhood', '#ChiefsKingdom', '#budweisercommercial', '#SBGCBotherhood', '#SBGCLambStreaker', '#SBGC20', '#SuperBowlCommercials', '#SuperBowlLV', '#HoosInTheSuperBowl', '#CowboysNation', '#GradisharF', '#Su', '#NFL', '#migos', '#ImAFan', '#floridaaquarium', '#BlackHistoryMonth', '#KCvsTB', '#Chiefs????', '#love', '#JimmyGIs', '#marketing', '#superbowlbest', '#tbt❤️', '#RocketMortgageSquares', '#oldestdudeontiktok', '#nflmvp', '#chief', '#2021', '#Buccaneer', '#SuperBowl\r\nhttps://t.co/SWrRmBXuKb', '#ChefsKingdom', '#A', '#tbt', '#SBLV', '#SuperBowl:', '#SupportLocal', '#https://rocketmortgagesquares.com/?ruid=be0acd4c-d112-4dce-bc51-3ac51f4d012c', '#podcast', '#St', '#COVID19', '#GoBucs', '#GetUpDC', '#PLN4FAM', '#brisketq', '#ohyeah', '#Super', '#GoChiefs', '#JRN3100', '#TomBrady', '#RunItBack', '#ThursdayThoughts', '#tampaevents', '#BroncosCountry', '#nfltwitter', '#Throw
# ...

# %%
dict_ca_21={}
hashtag_ca_21=[]
for i in range(0, len(df_ca1_2021)):
  k= df_ca1_2021.at[i,"text"]
  ind = [i.start() for i in re.finditer("#", k)]
  for j in range(len(ind)):
    ind1=k[ind[j]:].find(" ")
    if(ind1==-1):
      word=k[ind[j]:]
    else:
      word=k[ind[j]:ind1]
    if(word not in dict_ca_21):
      hashtag_ca_21.append(word)
      dict_ca_21[word]=1
print(hashtag_ca_21)
print("number of unique hashtags in CA 2021:" +str(len(hashtag_ca_21)-1))
# Out:
# ['', '#sbgcbrotherhood', '#TB12', '#WallpaperWednesday🏈via', '#football', '#SuperBowl', '#foo', '#sp', '#ArtificialIntelligence', '#HumanTrafficking', '#Super', '#countdown', '#SBLV', '#forthekids', '#covid', '#TampaBayLive55', '#S', '#GoBucs', '#Canadagetsscrewed', '#ridiculous', '#Prediction', '#supportlocalB', '#', '#canada\r\n#Ontario\r\n#COVID19', '#Ontario\r\n#COVID19', '#COVID19', '#PatrickMahomes', '#CrusherDestr', '#canadiantalent', '#WearAMask', '#SuperBowl\r\nhttps://t.co/zQN5uhgn7J', '#SuperBowl\r\n\r\nhttps://t.co/oyt9X8e0Gz', '#hellinahandbasket', '#SuperBowlWeekend', '#GoChiefs', '#NFL', '#tbtb12', '#BigGameSongsOrBands\r\nJesus', '#StayHomeON', '#goodvibes', '#FuckTheNFL', '#ISt', '#SuperBowl2021', '#Supe', '#COVIDIOTS', '#Sup', '#super', '#Su', '#wazzup', '#superbowl', '#NHL', '#SuperBowlWeeknd', '#LetsGoCanes', '#Mahomes', '#TheBoss', '#follobackforfolloback', '#SuperB', '#sundayvibes', '#foodiesofkitchener', '#FoodFacts', '#ChiefsKingdom', '#SuperbOwl', '#cake', '#
# ...

# %%
dict_gb_21={}
hashtag_gb_21=[]
for i in range(0, len(df_gb1_2021)):
  k= df_gb1_2021.at[i,"text"]
  ind = [i.start() for i in re.finditer("#", k)]
  for j in range(len(ind)):
    ind1=k[ind[j]:].find(" ")
    if(ind1==-1):
      word=k[ind[j]:]
    else:
      word=k[ind[j]:ind1]
    if(word not in dict_gb_21):
      hashtag_gb_21.append(word)
      dict_gb_21[word]=1
print(hashtag_gb_21)
print("number of unique hashtags in GB 2021:" +str(len(hashtag_gb_21)-1))
# Out:
# ['', '#SuperBowl', '#TheWeeknd', '#Lo', '#SBLV', '#FlyEaglesFly', '#YanksOut', '#Dominant', '#TBR54', '#channel4cricket', '#ChiefsKingdom', '#phillyinlondon', '#GoPats', '#SuperBowlLV', '#sixna', '#dogecoin', '#Dogecoi', '#Su', '#', '#KansasCityChiefs', '#DublinRacingFestival', '#S', '#BigGameSongsOrBands', '#MUFC', '#womeninsport', '#superbowl', '#YourOdds', '#DogecoinToTheMoon\r\nhttps://t.co/3dGZrkokpM', '#https://twitter.com/paddypower/status/1358134644487684103/photo/1', '#SuperBowlWeeknd', '#SuperbOwl\r\n#WWDITS', '#WWDITS', '#Supe', '#superbowlsu', '#NFLTwitter', '#Brady', '#GoBucs', '#SuperbowlSunday', '#Sup', '#superbOwl', '#NFL', '#wheresthefacepaint', '#Buccaneers', '#KCvsTB', '#SuperBowlSunday', '#THFC', '#TouchdownTom', '#TOTWBA', '#WhatIsHappeningInMyanmar', '#COYS', '#Chie', '#SuperB', '#SuperBowl2021', '#SuperbOwl', '#SuperMole!', '#requestabet', '#xrpthestandard', '#HereWeGo', '#ChiefsvsBuccaneers', '#RunItBack', '#gamble', '#nflgameday', '#ToTheMoon', '#RequestABet'
# ...

# %%
percent_us_21=(len(hashtag_us_21)-1)*100/df_us_2021.shape[0]
percent_ca_21=(len(hashtag_ca_21)-1)*100/df_ca_2021.shape[0]
percent_gb_21=(len(hashtag_gb_21)-1)*100/df_gb_2021.shape[0]
print("percentage of unique hashtags per unit tweets in US 2021:"+ str(percent_us_21))
print("percentage of unique hashtags per unit tweets in CA 2021:"+ str(percent_ca_21))
print("percentage of unique hashtags per unit tweets in GB 2021:"+ str(percent_gb_21))
# Out:
# percentage of unique hashtags per unit tweets in US 2021:6.3366102096411225
# percentage of unique hashtags per unit tweets in CA 2021:9.053651266766021
# percentage of unique hashtags per unit tweets in GB 2021:8.314350797266515

# %% [markdown]
# # Unique hashtags count 2020

# %%
df_us_20=pd.read_csv("US_2020.csv")
df_ca_20=pd.read_csv("CA_2020.csv")
df_gb_20=pd.read_csv("GB_2020.csv")

# %%
df_us1_20=df_us_20.iloc[:,[1]]
df_ca1_20=df_ca_20.iloc[:,[1]]
df_gb1_20=df_gb_20.iloc[:,[1]]

# %%
#dropping null values
df_us1_20.dropna(inplace = True)
df_ca1_20.dropna(inplace = True)
df_gb1_20.dropna(inplace = True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)

# %%
dict_us_20={}
hashtag_us_20=[]
for i in range(0, len(df_us1_20)):
  k= df_us1_20.at[i,"text"]
  ind = [i.start() for i in re.finditer("#", k)]
  for j in range(len(ind)):
    ind1=k[ind[j]:].find(" ")
    if(ind1==-1):
      word=k[ind[j]:]
    else:
      word=k[ind[j]:ind1]
    if(word not in dict_us_20):
      hashtag_us_20.append(word)
      dict_us_20[word]=1
print(hashtag_us_20)
print("number of unique hashtags in US 2020:" +str(len(hashtag_us_20)-1))
# Out:
# ['', '#Chiefs', '#Miami', '#BigGame', '#emaw', '#SuperBowlWeekend', '#HarryS', '#DenofChamp', '#lavobowl', '#taobowl', '#', '#SUPERBO', '#SuperBowLIV', '#nfl', '#foo', '#amazing', '#Mood', '#failuref', '#Car', '#RedFriday', '#ArrowheadPride', '#NFLTwitter', '#SuperBowlLIV', '#ChiefsKingdom', '#15girls#youthretre', '#yo', '#FlashbackFriday', '#CharlesVanFrickinMoron', '#Liv', '#SuperB', '#Yeesh', '#DreamBig', '#LiveItMiami', '#isitsundayyet', '#SuperBowl', '#Supe', '#SFvsKC', '#👀', '#Maddow', '#LastWord', '#AllACessIndy', '#FOX2', '#Super', '#partyplanner', '#WODB', '#superBrawlii', '#SBLIV', '#Superbowl', '#sippinonlipton', '#World', '#pricedout', '#C', '#Pat', '#Home', '#SuperBowl2020', '#EagleNation', '#BroncosCountry', '#GoldBlooded', '#GoLowDems', '#polls', '#beertenderlife', '#KobeForever', '#ohgodpleasemakeitstop', '#KickHunger', '#JLo', '#AccordingtoPete', '#tacos', '#ThotVentures', '#LIV', '#freestylefriday', '#Resist', '#YouOnlyLiveOnce', '#GiantsPride', '#RT', '#Sup', '#jov
# ...

# %%
dict_ca_20={}
hashtag_ca_20=[]
for i in range(0, len(df_ca1_20)):
  k= df_ca1_20.at[i,"text"]
  ind = [i.start() for i in re.finditer("#", k)]
  for j in range(len(ind)):
    ind1=k[ind[j]:].find(" ")
    if(ind1==-1):
      word=k[ind[j]:]
    else:
      word=k[ind[j]:ind1]
    if(word not in dict_ca_20):
      hashtag_ca_20.append(word)
      dict_ca_20[word]=1
print(hashtag_ca_20)
print("number of unique hashtags in CA 2020:" +str(len(hashtag_ca_20)-1))
# Out:
# ['', '#Keepingitreal', '#KickToWin', '#Sup', '#IT', '#SuperBowLIV', '#lovecanada', '#Kansas', '#reme', '#FM93', '#SuperBowl', '#AustralianOpen', '#superbowl', '#game', '#SuperbOwl', '#NFL100', '#superb', '#JouezPourGagner', '#SuperBowlLIV', '#NFLTwitter', '#GOJHL', '#SuperB', '#Sunday', '#partner', '#GoNiners', '#NotGoodWithMath', '#SUPERBOWL', '#FaithfulThenFaithfulNow', '#SuperBowl,', '#Niners', '#SBLIV', '#writers', '#SuperBowl?', '#Superbowlbets', '#happy', '#groun', '#Etobic', '#SuperBowl.', '#', '#GroundhogDay2020', '#SuperBo', '#S', '#h', '#cdnecon', '#Goputin', '#Patriots', '#Ch', '#Supe', '#Chiefs', '#sup', '#idontwatchfootball', '#KatieSowers', '#LesChiefs', '#rabid', '#JeepG', '#SuperBowl2020', '#USA', '#rams', '#DemiLovato', '#Go49ers', '#BetYourWay', '#Demi4HalfTime2021', '#SBLIV\xa0\r\nhttps://t.co/77rkeIAK0q', '#RaiderNation', '#SuperBowlSunday', '#thrift', '#GoChiefsGo', '#oilers', '#nice', '#kidscanada', '#BankruptDonny', '#KCvsSF', '#Superbowl', '#SuperBowl\r\n', '#
# ...

# %%
dict_gb_20={}
hashtag_gb_20=[]
for i in range(0, len(df_gb1_20)):
  k= df_gb1_20.at[i,"text"]
  ind = [i.start() for i in re.finditer("#", k)]
  for j in range(len(ind)):
    ind1=k[ind[j]:].find(" ")
    if(ind1==-1):
      word=k[ind[j]:]
    else:
      word=k[ind[j]:ind1]
    if(word not in dict_gb_20):
      hashtag_gb_20.append(word)
      dict_gb_20[word]=1
print(hashtag_gb_20)
print("number of unique hashtags in GB 2020:" +str(len(hashtag_gb_20)-1))
# Out:
# ['', '#ThankYou', '#humantrafficking', '#SuperbOwl', '#', '#NFL100', '#SuperBowl', '#SuperBowl\r\nShakira', '#S', '#WWE', '#KCvsSF', '#HappyBirthday', '#super', '#SuperBowLIV', '#Supe', '#SuperBowl2020', '#sofatime', '#SanFrancisco49ers', '#ChiefsKingdom', '#Super', '#SuperBowlLIV', '#RequestABet', '#NFL', '#Football?', '#de', '#Sup', '#SuperBowlSunday', '#NotStayingUp\r\n#SuperBowlnaESPN', '#SuperBowlnaESPN', '#49ers', '#SuperSunday', '#Technology', '#49ersvschiefs', '#YourOdds', '#Stee', '#SuperBowlS', '#SuperSaturdayNight', '#SuperBow', '#Miami', '#AIinPR\r\nhttps://t.co/s8iEz3tTrQ', '#bcafc', '#NFLTwitter', '#KansasCityChiefs', '#NFLTwitter\r\n\r\n#SuperBowl', '#SUPERBowl.', '#englishman', '#COYS', '#callthemidwife', '#SBLIV', '#Chiefsvs49ers', '#superbowl', '#SuperBowl\r\n#KansasCityChiefs\r\n#SanFrancisco49ers\r\n#Chiefs\r\n#49ers\r\n🇺🇸', '#KansasCityChiefs\r\n#SanFrancisco49ers\r\n#Chiefs\r\n#49ers\r\n🇺🇸', '#SanFrancisco49ers\r\n#Chiefs\r\n#49ers\r\n🇺🇸', '#Chiefs\r\n#49ers\r\n
# ...

# %%
percent_us_20=(len(hashtag_us_20)-1)*100/df_us_20.shape[0]
percent_ca_20=(len(hashtag_ca_20)-1)*100/df_ca_20.shape[0]
percent_gb_20=(len(hashtag_gb_20)-1)*100/df_gb_20.shape[0]
print("percentage of unique hashtags per unit tweets in US 2020:"+ str(percent_us_20))
print("percentage of unique hashtags per unit tweets in CA 2020:"+ str(percent_ca_20))
print("percentage of unique hashtags per unit tweets in GB 2020:"+ str(percent_gb_20))
# Out:
# percentage of unique hashtags per unit tweets in US 2020:6.897243778431897
# percentage of unique hashtags per unit tweets in CA 2020:9.356936416184972
# percentage of unique hashtags per unit tweets in GB 2020:9.880609304240428

# %% [markdown]
# # Unique hashtags count 2019

# %%
df_us_19=pd.read_csv("US_2019.csv")
df_ca_19=pd.read_csv("CA_2019.csv")
df_gb_19=pd.read_csv("GB_2019.csv")

# %%
df_us1_19=df_us_19.iloc[:,[1]]
df_ca1_19=df_ca_19.iloc[:,[1]]
df_gb1_19=df_gb_19.iloc[:,[1]]

# %%
#dropping null values
df_us1_19.dropna(inplace = True)
df_ca1_19.dropna(inplace = True)
df_gb1_19.dropna(inplace = True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)

# %%
dict_us_19={}
hashtag_us_19=[]
for i in range(0, len(df_us1_19)):
  k= df_us1_19.at[i,"text"]
  ind = [i.start() for i in re.finditer("#", k)]
  for j in range(len(ind)):
    ind1=k[ind[j]:].find(" ")
    if(ind1==-1):
      word=k[ind[j]:]
    else:
      word=k[ind[j]:ind1]
    if(word not in dict_us_19):
      hashtag_us_19.append(word)
      dict_us_19[word]=1
print(hashtag_us_19)
print("number of unique hashtags in US 2019:" +str(len(hashtag_us_19)-1))
# Out:
# ['', '#SuperBowl', '#LiveHipHopDaily', '#', '#LARams', '#LPT:', '#Pat', '#superbowl', '#ThrowbackThursday:', '#SBLIII', '#Super', '#QualityTime', '#PhilSimms', '#maroon5sundaymorningbyexo', '#rams', '#Atlanta', '#classic', '#NoT', '#StanStillStinks', '#BradySucks', '#superb', '#excellence', '#Steelers', '#philadelphiaisbetter', '#GOAT4SIX', '#SuperBowlLIII', '#DriveSober', '#IBMSummitProgram', '#WhyNotUs', '#SBGC2019', '#superbowlgospelc', '#SBLiii', '#S', '#sup', '#sportsbetting', '#thankyou', '#Repost', '#ATL', '#SUPERBOWLWE', '#TheWorldsBest', '#tbt', '#Su', '#CWOpenToAll', '#nba', '#NotMySuperBowl', '#BigT', '#lifeofinman', '#PSA:', '#GamblingTwitter', '#Superbowl', '#SuperBowlcommercials', '#Throwbac', '#digita', '#thethymepizzeria', '#LasVegas', '#supe', '#vacaciones', '#whoa', '#SuperBowLIII', '#Sa', '#Di', '#abc7eyewitness', '#49ers', '#Sup', '#FundaySunday', '#GOPATRIOTS', '#FrozLanta', '#ReggieWhite', '#MSBCGA', '#Freepicks', '#SmartNews', '#goRams', '#awesomeday', '#recipe
# ...

# %%
dict_ca_19={}
hashtag_ca_19=[]
for i in range(0, len(df_ca1_19)):
  k= df_ca1_19.at[i,"text"]
  ind = [i.start() for i in re.finditer("#", k)]
  for j in range(len(ind)):
    ind1=k[ind[j]:].find(" ")
    if(ind1==-1):
      word=k[ind[j]:]
    else:
      word=k[ind[j]:ind1]
    if(word not in dict_ca_19):
      hashtag_ca_19.append(word)
      dict_ca_19[word]=1
print(hashtag_ca_19)
print("number of unique hashtags in CA 2019:" +str(len(hashtag_ca_19)-1))
# Out:
# ['', '#superbowlparty', '#SuperBowl', '#bu', '#WeTheNorth', '#SuperBowl!', '#Podcast', '#FridayMotivation', '#FridayThoughts', '#VegasBorn', '#OneForMe', '#GoPatriots', '#yablewit', '#SuperBowlLIII', '#Canadian', '#EntertainmentNews', '#NFL', '#deerinheadlights', '#superbo', '#EverythingWeGot', '#DontDrinkandDrive', '#Tom', '#Habs', '#super', '#U', '#GOJHL', '#bigsbowl.', '#', '#SuperBowl?', '#Canucks', '#SuperbOwl', '#SBLIII', '#YYZ', '#SaturdayMo', '#superbowl', '#takedownthepats', '#Superbowl', '#needbetterodds', '#sportsbiz', '#openhouse', '#Rams', '#dumbfounded', '#Super', '#SuperBowlWee', '#EXCLU:', '#SMM', '#Canadiens', '#Jesus\r\n#JesusSaves\r\n#SuperBowl\r\n#SaturdayThoughts', '#JesusSaves\r\n#SuperBowl\r\n#SaturdayThoughts', '#SuperBowl\r\n#SaturdayThoughts', '#SaturdayThoughts', '#PollTime', '#Supe', '#SuperBowl53', '#Ha', '#illputitbackiswear', '#socrowded', '#chilli', '#S', '#MENCS', '#TostitosAndSalsa', '#SB53', '#wwe', '#SuperSaturdayNight', '#SuperBowl2019', '#SuperBo
# ...

# %%
dict_gb_19={}
hashtag_gb_19=[]
for i in range(0, len(df_gb1_19)):
  k= df_gb1_19.at[i,"text"]
  ind = [i.start() for i in re.finditer("#", k)]
  for j in range(len(ind)):
    ind1=k[ind[j]:].find(" ")
    if(ind1==-1):
      word=k[ind[j]:]
    else:
      word=k[ind[j]:ind1]
    if(word not in dict_gb_19):
      hashtag_gb_19.append(word)
      dict_gb_19[word]=1
print(hashtag_gb_19)
print("number of unique hashtags in GB 2019:" +str(len(hashtag_gb_19)-1))
# Out:
# ['', '#FFC', '#HornsUp', '#GoRams', '#nfl', '#SuperbOwl', '#americanfootballuk\r\nhttps://t.co/s2WXjFalr9', '#Superbowl', '#Requestabet', '#superbowl', '#SuperBowl', '#SB53', '#Supe', '#SBLIII\r\n\r\nhttps://t.co/TXAMm13dS6', '#SBLIII', '#ukraidernation', '#NFL', '#', '#WhoDat', '#SixNations2019', '#Celtic', '#princes', '#taketheknee', '#bla', '#oneteamcommitted', '#SuperBowlWeek', '#EVEWOL', '#touchdown', '#Req', '#goatinamagahat', '#LAChar', '#anyonebutNE', '#NCFC', '#superBowl', '#SuperBowl2019', '#EverythingWeGot', '#TheBowlMovement', '#SuperBowl2019Live', '#SuperBowlLIII', '#sports', '#gopats', '#anyonebutthepatriots', '#hailhail', '#SundayFunday', '#GameFace', '#HannaTV', '#Marvel', '#reallysuperbowl', '#SuperBowl53', '#ThunderUp', '#Patriots', '#nfluk', '#GoPats', '#larams', '#Sup', '#suoerbowlsundae', '#S', '#Rams', '#supe', '#whoshouse', '#TrendingNow', '#Hammerheads', '#SuperBowlSunday', '#KeepTheFaith', '#anyonebutthepats', '#superbowl53', '#Southamp', '#Super', '#oldmaste
# ...

# %%
percent_us_19=(len(hashtag_us_19)-1)*100/df_us_19.shape[0]
percent_ca_19=(len(hashtag_ca_19)-1)*100/df_ca_19.shape[0]
percent_gb_19=(len(hashtag_gb_19)-1)*100/df_gb_19.shape[0]
print("percentage of unique hashtags per unit tweets in US 2019:"+ str(percent_us_19))
print("percentage of unique hashtags per unit tweets in CA 2019:"+ str(percent_ca_19))
print("percentage of unique hashtags per unit tweets in GB 2019:"+ str(percent_gb_19))
# Out:
# percentage of unique hashtags per unit tweets in US 2019:7.47531163995467
# percentage of unique hashtags per unit tweets in CA 2019:10.807453416149068
# percentage of unique hashtags per unit tweets in GB 2019:9.04442313838287

# %% [markdown]
# # Unique hashtags count 2018

# %%
df_us_18=pd.read_csv("US_2018.csv")
df_ca_18=pd.read_csv("CA_2018.csv")
df_gb_18=pd.read_csv("GB_2018.csv")

# %%
df_us1_18=df_us_18.iloc[:,[1]]
df_ca1_18=df_ca_18.iloc[:,[1]]
df_gb1_18=df_gb_18.iloc[:,[1]]

# %%
#dropping null values
df_us1_18.dropna(inplace = True)
df_ca1_18.dropna(inplace = True)
df_gb1_18.dropna(inplace = True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)

# %%
dict_us_18={}
hashtag_us_18=[]
for i in range(0, len(df_us1_18)):
  k= df_us1_18.at[i,"text"]
  ind = [i.start() for i in re.finditer("#", k)]
  for j in range(len(ind)):
    ind1=k[ind[j]:].find(" ")
    if(ind1==-1):
      word=k[ind[j]:]
    else:
      word=k[ind[j]:ind1]
    if(word not in dict_us_18):
      hashtag_us_18.append(word)
      dict_us_18[word]=1
print(hashtag_us_18)
print("number of unique hashtags in US 2018:" +str(len(hashtag_us_18)-1))
# Out:
# ['#SuperbOwl?', '#Super', '#sp', '', '#FlyE', '#BoundaryBayBeerDelivery', '#FlyEaglesFly', '#nooxygen', '#Ea', '#Foodiechats', '#Patriots', '#OTGexp', '#S', '#UncleLuke', '#SuperBowlLII', '#SuperBowl', '#VegasBigGame', '#MentalHealth', '#EastBoston', '#Repost', '#WestCoas', '#YakutianDiamon', '#superbow', '#PlayersOnly', '#Gronkowski', '#GoPats', '#boldnorth', '#s', '#Chen\r\nhttps://t.co/O7SGiLzz3a', '#foodtravelchat', '#WeLoveLA', '#SportsRoadhouse', '#SBLII', '#TAILGATE', '#SuperBowlExperience\r\nDoing', '#SeaSa', '#Ste', '#Steelers', '#eaglesfans', '#BigGamePlansIn4Words', '#FoodieChats', '#wowprepare', '#Billions', '#NationalHoliday', '#1', '#SB52', '#da', '#superbowl', '#Su', '#SurpriseMe', '#aloha', '#', '#powderhornpark', '#birthdayshenanagans', '#VMStudio58', '#SuperBowl2018', '#HereWeGo', '#superbowlparty', '#MichaelJackson\r\n#KingOfPop\r\n#SuperBowlLegend\r\n#HalftimeShow\r\nhttps://t.co/vNHcIwRvFd', '#KingOfPop\r\n#SuperBowlLegend\r\n#HalftimeShow\r\nhttps://t.co/vNHcIwR
# ...

# %%
dict_ca_18={}
hashtag_ca_18=[]
for i in range(0, len(df_ca1_18)):
  k= df_ca1_18.at[i,"text"]
  ind = [i.start() for i in re.finditer("#", k)]
  for j in range(len(ind)):
    ind1=k[ind[j]:].find(" ")
    if(ind1==-1):
      word=k[ind[j]:]
    else:
      word=k[ind[j]:ind1]
    if(word not in dict_ca_18):
      hashtag_ca_18.append(word)
      dict_ca_18[word]=1
print(hashtag_ca_18)
print("number of unique hashtags in CA 2018:" +str(len(hashtag_ca_18)-1))
# Out:
# ['', '#Superbowl', '#BellLetsTalk', '#SuperBowl', '#Stigmabase', '#NFLPlayoffs\r\n#PHIvsNE\r\n#SuperBowl\xa0\r\n#SuperBowlLII\r\n#SBLII\xa0\r\n#SB52\xa0\r\n#Patriots\r\n#Eagles\xa0\r', '#PHIvsNE\r\n#SuperBowl\xa0\r\n#SuperBowlLII\r\n#SBLII\xa0\r\n#SB52\xa0\r\n#Patri', '#SuperBowl\xa0\r\n#SuperBowlLII\r\n#SBLII\xa0\r\n#SB5', '#SuperBowlLII\r\n', '#Brady', '#noalaramclock', '#SuperBowl\r\nhttps://t.co/8mpZMhW0Ko', '#sportsbiz', '#PepsiHalftime', '#Eagles', '#Economy', '#FunniestThingIveSaidAllWeek', '#DillyDilly', '#CofefeInChief', '#SuperBowl???', '#RealConversationsWithKids', '#', '#TheFourChallenge', '#voteforme', '#AdamLevine😂', '#MaddenClu', '#FlyEaglesFly', '#PHIvsNE', '#NFL', '#tacos', '#S', '#YYC', '#Supe', '#SuperBowlLII', '#facepalm', '#superbowl', '#bradyisacakeeater', '#thatfeelingwhen', '#SuperBowl#football#food#sports#westmount#homemade#montr', '#football#food#sports#westmount#home', '#food#sports#westm', '#sports#', '#Football', '#FoodieFriday', '#Habs', '#PhillyPhilly',
# ...

# %%
dict_gb_18={}
hashtag_gb_18=[]
for i in range(0, len(df_gb1_18)):
  k= df_gb1_18.at[i,"text"]
  ind = [i.start() for i in re.finditer("#", k)]
  for j in range(len(ind)):
    ind1=k[ind[j]:].find(" ")
    if(ind1==-1):
      word=k[ind[j]:]
    else:
      word=k[ind[j]:ind1]
    if(word not in dict_gb_18):
      hashtag_gb_18.append(word)
      dict_gb_18[word]=1
print(hashtag_gb_18)
print("number of unique hashtags in GB 2018:" +str(len(hashtag_gb_18)-1))
# Out:
# ['#SuperBowl', '', '#Patriots', '#superbowl', '#MLB', '#MGT358', '#TBT', '#Superbowl2018', '#Cant', '#BeerPong', '#legend', '#S', '#AskAPat', '#Prince', '#Priorities', '#requestabet', '#flyeaglesfly', '#FridayFeeling', '#FlyEaglesFly', '#huthuthut', '#Superbowl', '#SnatchNFL', '#RequestABet', '#freeb', '#patsnation', '#sportsball', '#FastAndStillSatisfying\r\nhttp', '#snatchNFL', '#SB52', '#Just', '#Sup', '#FOMO', '#LetsGoooooo', '#Super', '#SuperBowlLII', '#Eagles', '#marketing', '##SuperBowl', '#sendhelp', '#snatchnfl', '#su', '#SBLII', '#OnThisDay', '#music', '#BlackSabbath', '#revsion', '#s', '#gridiron', '#SuperBowlWeekend', "#BlackSabbath's", '#WBA', '#6Nations2018', '#SuperBowl52', '#🦅🏈\r\n#SuperBowl', '#Supe', '#maninthewoods', '#YourOdds', '#yourcall', '#HTTR', '#Patriots#allnighter', '#allnighter', '#AskGia', '#', '#NYGiants', '#TuckRule', '#SkySport', '#JustinTimberlake', '#Stoked', '#Snatchnfl', '#Minneapolis', '#NotDone', '#BBCBreakfast:', '#GoPats', '#FlyEagleFly', '#Su
# ...

# %%
percent_us_18=(len(hashtag_us_18)-1)*100/df_us_18.shape[0]
percent_ca_18=(len(hashtag_ca_18)-1)*100/df_ca_18.shape[0]
percent_gb_18=(len(hashtag_gb_18)-1)*100/df_gb_18.shape[0]
print("percentage of unique hashtags per unit tweets in US 2018:"+ str(percent_us_18))
print("percentage of unique hashtags per unit tweets in CA 2018:"+ str(percent_ca_18))
print("percentage of unique hashtags per unit tweets in GB 2018:"+ str(percent_gb_18))
# Out:
# percentage of unique hashtags per unit tweets in US 2018:7.519477453372157
# percentage of unique hashtags per unit tweets in CA 2018:12.847033206314643
# percentage of unique hashtags per unit tweets in GB 2018:9.84688489968321

# %% [markdown]
# # Unique hashtags count 2017

# %%
df_ca_17=pd.read_csv("CA_2017.csv")
df_gb_17=pd.read_csv("GB_2017.csv")

# %%
df_ca1_17=df_ca_17.iloc[:,[1]]
df_gb1_17=df_gb_17.iloc[:,[1]]

# %%
df_ca1_17.dropna(inplace = True)
df_gb1_17.dropna(inplace = True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)

# %%
dict_ca_17={}
hashtag_ca_17=[]
for i in range(0, len(df_ca1_17)):
  k= df_ca1_17.at[i,"text"]
  ind = [i.start() for i in re.finditer("#", k)]
  for j in range(len(ind)):
    ind1=k[ind[j]:].find(" ")
    if(ind1==-1):
      word=k[ind[j]:]
    else:
      word=k[ind[j]:ind1]
    if(word not in dict_ca_17):
      hashtag_ca_17.append(word)
      dict_ca_17[word]=1
print(hashtag_ca_17)
print("number of unique hashtags in CA 2017:" +str(len(hashtag_ca_17)-1))
# Out:
# ['', '#Superbowl', '#Coe', '#AlternativeFacts', '#yxesuperKFC', '#GTFO', '#SB51', '#Super', '#RiseUp', '#S', '#superbowl\r\n\r\nhttps://t.co/bMOV6upYC6', '#Repost', '#notbuyingit', '#SuperBowl', '#womensri', '#InTheLoop', '#ldnont', '#Supe', '#BadSuperBowlParty', '#gameday', '#GameDayFood', '#superbowl', '#wingsvernon', '#thebeaverton', '#PatsNation', '#patriots', '#Drivefor5', '#badliprea', '#BrodyAndJess', '#super', '#SuperBowl!', '#ads', '#MédiasSociaux', '#Pepsi', '#SocialMedia', '#Football', '#Predictions', '#Brady', '#unlimitedMoves', '#Commercials', '#really', '#LIBERALFEARS', '#FrederickDouglass.', '#canada150\xa0', '#Patriots', '#Patr', '#c', '#awesome', '#putin', '#ladygaga', '#feast', '#FridayFeeling', '#sports', '#gridiron', '#uniforms', '#GroundhogDay', '#SuperBow2017', '#theresashoeforthat', '#P', '#photography', '#chili', '#SuperBowl2017', '#LadyGaga', '#4', '#TGIF', '#officewit', '#FRESHTO', '#curedd', '#', '#RockinHal', '#Level4ed', '#SuperBowlSunday', '#ld', '#s', '
# ...

# %%
dict_gb_17={}
hashtag_gb_17=[]
for i in range(0, len(df_gb1_17)):
  k= df_gb1_17.at[i,"text"]
  ind = [i.start() for i in re.finditer("#", k)]
  for j in range(len(ind)):
    ind1=k[ind[j]:].find(" ")
    if(ind1==-1):
      word=k[ind[j]:]
    else:
      word=k[ind[j]:ind1]
    if(word not in dict_gb_17):
      hashtag_gb_17.append(word)
      dict_gb_17[word]=1
print(hashtag_gb_17)
print("number of unique hashtags in GB 2017:" +str(len(hashtag_gb_17)-1))
# Out:
# ['', '#SuperBowl2017', '#DumpTrump', '#SB51', '#Falcons', '#CamsHats', '#RISEUPLEEDS', '#SuperBowl', '#joanne', '#OnlyInTheNFL', '#PepsiHalftime', '#NintendoSw', '#gaga', '#London', '#Gaga', '#WGUAFC', '#S', '#SuperbOwl...', '#iconic\r\nhttps://t.co/V4CsS5fdkZ', '#NFLUK', '#N', '#Req', '#RequestABet', '#superBowl', '#GOTEXANS', '#', '#music', '#salt', '#superbowl', '#LiveSport\r\nhttps://t.co/RtpZ8TG1d1', '#s', '#Atlanta', '#showbiz', '#Sup', '#nfluk', '#FridayFeeling', '#SpaceCity.\r\nhttps://t.co/wBRu1VlkJK', '#BowlAtTheBot', '#MichaelJackson,', '#OneMore', '#SUPERBOWL', '#Supe', '#windyourneckin', '#FTW', '#FlashbackFriday', '#USA', '#Patriots', '#SuperBowlWeekend', '#PatsNation', '#AucklandNines', '#RiseUp', '#Superbowl', '#Hope4Corrie', '#falcons', '#SuperBo', '#Touchdown', '#SuperBowl!', '#NewEnglandPatriots', '#keepitreal', '#nfl', '#6nations2017;', '#6nations2', '#NEvsATL', '#neworleans', '#DavisCup', '#Super', '#football', '#Foot', '#SixNationsRugby', '#sixnat', '#6nations',
# ...

# %%
percent_ca_17=(len(hashtag_ca_17)-1)*100/df_ca_17.shape[0]
percent_gb_17=(len(hashtag_gb_17)-1)*100/df_gb_17.shape[0]

print("percentage of unique hashtags per unit tweets in CA 2017:"+ str(percent_ca_17))
print("percentage of unique hashtags per unit tweets in GB 2017:"+ str(percent_gb_17))
# Out:
# percentage of unique hashtags per unit tweets in CA 2017:12.138465042131633
# percentage of unique hashtags per unit tweets in GB 2017:10.5170902716915

# %%
x=[2017,2018,2019,2020,2021]
y_us=[None,percent_us_18,percent_us_19,percent_us_20,percent_us_21]
y_ca=[percent_ca_17,percent_ca_18,percent_ca_19,percent_ca_20,percent_ca_21]
y_gb=[percent_gb_17,percent_gb_18,percent_gb_19,percent_gb_20,percent_gb_21]
plt.plot(x, y_us,"b")
plt.plot(x, y_ca,"r")
plt.plot(x, y_gb,"g")
plt.xlabel("Year")
plt.ylabel("Percent of unique hashtag")
plt.title('Percent of unique hashtag per tweet')
plt.show()

# %% [markdown]
# # **Tweet Time Analysis**

# %%
df_us2_2021=df_us_2021.iloc[:,[3]]
df_ca2_2021=df_ca_2021.iloc[:,[3]]
df_gb2_2021=df_gb_2021.iloc[:,[3]]

# %%
#dropping null values
df_us2_2021.dropna(inplace = True)
df_ca2_2021.dropna(inplace = True)
df_gb2_2021.dropna(inplace = True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)

# %%
def time_interval(c):
  h=(15*c)//60
  m=(15*c)%60
  if(m!=45):
    return str(h)+":"+str(m)+" - "+str(h)+":"+str(m+15)
  else:
    return str(h)+":"+str(m)+" - "+str(h+1)+":"+str(00)

# %%
hour_us_21=[0 for i in range(96)]
maxcount=0
time=0
for i in range(0, len(df_us2_2021)):
  numh= int(df_us2_2021.at[i,"created_at"][11:13])
  numm= int(df_us2_2021.at[i,"created_at"][14:16])
  hour_us_21[((numh*60)+numm)//15-1]=hour_us_21[((numh*60)+numm)//15-1]+1
  if(hour_us_21[((numh*60)+numm)//15-1]>maxcount):
    time=((numh*60)+numm)//15
    maxcount=hour_us_21[((numh*60)+numm)//15-1]
print("maximum number of tweets in US 2021 took place between: "+time_interval(time))
# Out:
# maximum number of tweets in US 2021 took place between: 15:45 - 16:0

# %%
hour_ca_21=[0 for i in range(96)]
maxcount=0
time=0
for i in range(0, len(df_ca2_2021)):
  numh= int(df_ca2_2021.at[i,"created_at"][11:13])
  numm= int(df_ca2_2021.at[i,"created_at"][14:16])
  hour_ca_21[((numh*60)+numm)//15-1]=hour_ca_21[((numh*60)+numm)//15-1]+1
  if(hour_ca_21[((numh*60)+numm)//15-1]>maxcount):
    time=((numh*60)+numm)//15
    maxcount=hour_ca_21[((numh*60)+numm)//15-1]
print("maximum number of tweets in CA 2021 took place between: "+time_interval(time))
# Out:
# maximum number of tweets in CA 2021 took place between: 1:45 - 2:0

# %%
hour_gb_21=[0 for i in range(96)]
maxcount=0
time=0
for i in range(0, len(df_gb2_2021)):
  numh= int(df_gb2_2021.at[i,"created_at"][11:13])
  numm= int(df_gb2_2021.at[i,"created_at"][14:16])
  hour_gb_21[((numh*60)+numm)//15-1]=hour_gb_21[((numh*60)+numm)//15-1]+1
  if(hour_gb_21[((numh*60)+numm)//15-1]>maxcount):
    time=((numh*60)+numm)//15
    maxcount=hour_gb_21[((numh*60)+numm)//15-1]
print("maximum number of tweets in GB 2021 took place between: "+time_interval(time))
# Out:
# maximum number of tweets in GB 2021 took place between: 1:30 - 1:45

# %% [markdown]
# # Tweet Time Analysis 2020

# %%
df_us2_20=df_us_20.iloc[:,[3]]
df_ca2_20=df_ca_20.iloc[:,[3]]
df_gb2_20=df_gb_20.iloc[:,[3]]

# %%
#dropping null values
df_us2_20.dropna(inplace = True)
df_ca2_20.dropna(inplace = True)
df_gb2_20.dropna(inplace = True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)

# %%
hour_us_20=[0 for i in range(96)]
maxcount=0
time=0
for i in range(0, len(df_us2_20)):
  numh= int(df_us2_20.at[i,"created_at"][11:13])
  numm= int(df_us2_20.at[i,"created_at"][14:16])
  hour_us_20[((numh*60)+numm)//15-1]=hour_us_20[((numh*60)+numm)//15-1]+1
  if(hour_us_20[((numh*60)+numm)//15-1]>maxcount):
    time=((numh*60)+numm)//15
    maxcount=hour_us_20[((numh*60)+numm)//15-1]
print("maximum number of tweets in US 2020 took place between: "+time_interval(time))
# Out:
# maximum number of tweets in US 2020 took place between: 16:45 - 17:0

# %%
hour_ca_20=[0 for i in range(96)]
maxcount=0
time=0
for i in range(0, len(df_ca2_20)):
  numh= int(df_ca2_20.at[i,"created_at"][11:13])
  numm= int(df_ca2_20.at[i,"created_at"][14:16])
  hour_ca_20[((numh*60)+numm)//15-1]=hour_ca_20[((numh*60)+numm)//15-1]+1
  if(hour_ca_20[((numh*60)+numm)//15-1]>maxcount):
    time=((numh*60)+numm)//15
    maxcount=hour_ca_20[((numh*60)+numm)//15-1]
print("maximum number of tweets in CA 2020 took place between: "+time_interval(time))
# Out:
# maximum number of tweets in CA 2020 took place between: 1:30 - 1:45

# %%
hour_gb_20=[0 for i in range(96)]
maxcount=0
time=0
for i in range(0, len(df_gb2_20)):
  numh= int(df_gb2_20.at[i,"created_at"][11:13])
  numm= int(df_gb2_20.at[i,"created_at"][14:16])
  hour_gb_20[((numh*60)+numm)//15-1]=hour_gb_20[((numh*60)+numm)//15-1]+1
  if(hour_gb_20[((numh*60)+numm)//15-1]>maxcount):
    time=((numh*60)+numm)//15
    maxcount=hour_gb_20[((numh*60)+numm)//15-1]
print("maximum number of tweets in GB 2021 took place between: "+time_interval(time))
# Out:
# maximum number of tweets in GB 2021 took place between: 23:30 - 23:45

# %% [markdown]
# # Tweet Time Analysis 2019

# %%
df_us2_19=df_us_19.iloc[:,[3]]
df_ca2_19=df_ca_19.iloc[:,[3]]
df_gb2_19=df_gb_19.iloc[:,[3]]

# %%
#dropping null values
df_us2_19.dropna(inplace = True)
df_ca2_19.dropna(inplace = True)
df_gb2_19.dropna(inplace = True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)

# %%
hour_us_19=[0 for i in range(96)]
maxcount=0
time=0
for i in range(0, len(df_us2_19)):
  numh= int(df_us2_19.at[i,"created_at"][11:13])
  numm= int(df_us2_19.at[i,"created_at"][14:16])
  hour_us_19[((numh*60)+numm)//15-1]=hour_us_19[((numh*60)+numm)//15-1]+1
  if(hour_us_19[((numh*60)+numm)//15-1]>maxcount):
    time=((numh*60)+numm)//15
    maxcount=hour_us_19[((numh*60)+numm)//15-1]
print("maximum number of tweets in US 2019 took place between: "+time_interval(time))
# Out:
# maximum number of tweets in US 2019 took place between: 17:45 - 18:0

# %%
hour_ca_19=[0 for i in range(96)]
maxcount=0
time=0
for i in range(0, len(df_ca2_19)):
  numh= int(df_ca2_19.at[i,"created_at"][11:13])
  numm= int(df_ca2_19.at[i,"created_at"][14:16])
  hour_ca_19[((numh*60)+numm)//15-1]=hour_ca_19[((numh*60)+numm)//15-1]+1
  if(hour_ca_19[((numh*60)+numm)//15-1]>maxcount):
    time=((numh*60)+numm)//15
    maxcount=hour_ca_19[((numh*60)+numm)//15-1]
print("maximum number of tweets in CA 2019 took place between: "+time_interval(time))
# Out:
# maximum number of tweets in CA 2019 took place between: 1:45 - 2:0

# %%
hour_gb_19=[0 for i in range(96)]
maxcount=0
time=0
for i in range(0, len(df_gb2_19)):
  numh= int(df_gb2_19.at[i,"created_at"][11:13])
  numm= int(df_gb2_19.at[i,"created_at"][14:16])
  hour_gb_19[((numh*60)+numm)//15-1]=hour_gb_19[((numh*60)+numm)//15-1]+1
  if(hour_gb_19[((numh*60)+numm)//15-1]>maxcount):
    time=((numh*60)+numm)//15
    maxcount=hour_gb_19[((numh*60)+numm)//15-1]
print("maximum number of tweets in GB 2019 took place between: "+time_interval(time))
# Out:
# maximum number of tweets in GB 2019 took place between: 23:30 - 23:45

# %% [markdown]
# # Tweet Time Analysis 2018

# %%
df_us2_18=df_us_18.iloc[:,[3]]
df_ca2_18=df_ca_18.iloc[:,[3]]
df_gb2_18=df_gb_18.iloc[:,[3]]

# %%
#dropping null values
df_us2_18.dropna(inplace = True)
df_ca2_18.dropna(inplace = True)
df_gb2_18.dropna(inplace = True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)

# %%
hour_us_18=[0 for i in range(96)]
maxcount=0
time=0
for i in range(0, len(df_us2_18)):
  numh= int(df_us2_18.at[i,"created_at"][11:13])
  numm= int(df_us2_18.at[i,"created_at"][14:16])
  hour_us_18[((numh*60)+numm)//15-1]=hour_us_18[((numh*60)+numm)//15-1]+1
  if(hour_us_18[((numh*60)+numm)//15-1]>maxcount):
    time=((numh*60)+numm)//15
    maxcount=hour_us_18[((numh*60)+numm)//15-1]
print("maximum number of tweets in US 2018 took place between: "+time_interval(time))
# Out:
# maximum number of tweets in US 2018 took place between: 16:45 - 17:0

# %%
hour_ca_18=[0 for i in range(96)]
maxcount=0
time=0
for i in range(0, len(df_ca2_18)):
  numh= int(df_ca2_18.at[i,"created_at"][11:13])
  numm= int(df_ca2_18.at[i,"created_at"][14:16])
  hour_ca_18[((numh*60)+numm)//15-1]=hour_ca_18[((numh*60)+numm)//15-1]+1
  if(hour_ca_18[((numh*60)+numm)//15-1]>maxcount):
    time=((numh*60)+numm)//15
    maxcount=hour_ca_18[((numh*60)+numm)//15-1]
print("maximum number of tweets in CA 2018 took place between: "+time_interval(time))
# Out:
# maximum number of tweets in CA 2018 took place between: 3:30 - 3:45

# %%
hour_gb_18=[0 for i in range(96)]
maxcount=0
time=0
for i in range(0, len(df_gb2_18)):
  numh= int(df_gb2_18.at[i,"created_at"][11:13])
  numm= int(df_gb2_18.at[i,"created_at"][14:16])
  hour_gb_18[((numh*60)+numm)//15-1]=hour_gb_18[((numh*60)+numm)//15-1]+1
  if(hour_gb_18[((numh*60)+numm)//15-1]>maxcount):
    time=((numh*60)+numm)//15
    maxcount=hour_gb_18[((numh*60)+numm)//15-1]
print("maximum number of tweets in GB 2018 took place between: "+time_interval(time))
# Out:
# maximum number of tweets in GB 2018 took place between: 23:45 - 24:0

# %% [markdown]
# # Tweet Time Analysis 2017

# %%
df_ca2_17=df_ca_17.iloc[:,[3]]
df_gb2_17=df_gb_17.iloc[:,[3]]

# %%
df_ca2_17.dropna(inplace = True)
df_gb2_17.dropna(inplace = True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)

# %%
hour_ca_17=[0 for i in range(96)]
maxcount=0
time=0
for i in range(0, len(df_ca2_17)):
  numh= int(df_ca2_17.at[i,"created_at"][11:13])
  numm= int(df_ca2_17.at[i,"created_at"][14:16])
  hour_ca_17[((numh*60)+numm)//15-1]=hour_ca_17[((numh*60)+numm)//15-1]+1
  if(hour_ca_17[((numh*60)+numm)//15-1]>maxcount):
    time=((numh*60)+numm)//15
    maxcount=hour_ca_17[((numh*60)+numm)//15-1]
print("maximum number of tweets in CA 2018 took place between: "+time_interval(time))
# Out:
# maximum number of tweets in CA 2018 took place between: 1:45 - 2:0

# %%
hour_gb_17=[0 for i in range(96)]
maxcount=0
time=0
for i in range(0, len(df_gb2_17)):
  numh= int(df_gb2_17.at[i,"created_at"][11:13])
  numm= int(df_gb2_17.at[i,"created_at"][14:16])
  hour_gb_17[((numh*60)+numm)//15-1]=hour_gb_17[((numh*60)+numm)//15-1]+1
  if(hour_gb_17[((numh*60)+numm)//15-1]>maxcount):
    time=((numh*60)+numm)//15
    maxcount=hour_gb_17[((numh*60)+numm)//15-1]
print("maximum number of tweets in GB 2018 took place between: "+time_interval(time))
# Out:
# maximum number of tweets in GB 2018 took place between: 23:45 - 24:0

# %% [markdown]
# Graph 2021

# %%
x=[i+1 for i in range(96)]
percent_us_21=[(i*100)//df_us_2021.shape[0] for i in hour_us_21]

plt.plot(x, percent_us_21,"b")
plt.xticks(rotation = 90)
plt.xlabel("Time interval")
plt.ylabel("Percent of tweets")
plt.title('Percent of tweets in the given time interval US 2021')
plt.show()

# %%
percent_ca_21=[(i*100)//df_ca_2021.shape[0] for i in hour_ca_21]
plt.plot(x, percent_ca_21,"r")
plt.xticks(rotation = 90)

plt.xlabel("Time interval")
plt.ylabel("Percent of tweets")
plt.title('Percent of tweets in the given time interval CA 2021')
plt.show()

# %%
percent_gb_21=[(i*100)//df_gb_2021.shape[0] for i in hour_gb_21]
plt.plot(x, percent_gb_21,"g")
plt.xticks(rotation = 90)
plt.xlabel("Time interval")
plt.ylabel("Percent of tweets")
plt.title('Percent of tweets in the given time interval GB 2021')
plt.show()

# %% [markdown]
# Graph 2020

# %%
x=[i+1 for i in range(96)]
percent_us_20=[(i*100)//df_us_20.shape[0] for i in hour_us_20]

plt.plot(x, percent_us_20,"b")
plt.xticks(rotation = 90)
plt.xlabel("Time interval")
plt.ylabel("Percent of tweets")
plt.title('Percent of tweets in the given time interval US 2020')
plt.show()

# %%
percent_ca_20=[(i*100)//df_ca_20.shape[0] for i in hour_ca_20]
plt.plot(x, percent_ca_20,"r")
plt.xticks(rotation = 90)

plt.xlabel("Time interval")
plt.ylabel("Percent of tweets")
plt.title('Percent of tweets in the given time interval CA 2020')
plt.show()

# %%
percent_gb_20=[(i*100)//df_gb_20.shape[0] for i in hour_gb_20]
plt.plot(x, percent_gb_20,"g")
plt.xticks(rotation = 90)
plt.xlabel("Time interval")
plt.ylabel("Percent of tweets")
plt.title('Percent of tweets in the given time interval GB 2020')
plt.show()

# %% [markdown]
# Graph 2019

# %%
x=[i+1 for i in range(96)]
percent_us_19=[(i*100)//df_us_19.shape[0] for i in hour_us_19]

plt.plot(x, percent_us_19,"b")
plt.xticks(rotation = 90)
plt.xlabel("Time interval")
plt.ylabel("Percent of tweets")
plt.title('Percent of tweets in the given time interval US 2019')
plt.show()

# %%
percent_ca_19=[(i*100)//df_ca_19.shape[0] for i in hour_ca_19]
plt.plot(x, percent_ca_19,"r")
plt.xticks(rotation = 90)

plt.xlabel("Time interval")
plt.ylabel("Percent of tweets")
plt.title('Percent of tweets in the given time interval CA 2019')
plt.show()

# %%
percent_gb_19=[(i*100)//df_gb_19.shape[0] for i in hour_gb_19]
plt.plot(x, percent_gb_19,"g")
plt.xticks(rotation = 90)
plt.xlabel("Time interval")
plt.ylabel("Percent of tweets")
plt.title('Percent of tweets in the given time interval GB 2019')
plt.show()

# %% [markdown]
# Graph 2018

# %%
x=[i+1 for i in range(96)]
percent_us_18=[(i*100)//df_us_18.shape[0] for i in hour_us_18]

plt.plot(x, percent_us_18,"b")
plt.xticks(rotation = 90)
plt.xlabel("Time interval")
plt.ylabel("Percent of tweets")
plt.title('Percent of tweets in the given time interval US 2018')
plt.show()

# %%
percent_ca_18=[(i*100)//df_ca_18.shape[0] for i in hour_ca_18]
plt.plot(x, percent_ca_18,"r")
plt.xticks(rotation = 90)

plt.xlabel("Time interval")
plt.ylabel("Percent of tweets")
plt.title('Percent of tweets in the given time interval CA 2018')
plt.show()

# %%
percent_gb_18=[(i*100)//df_gb_18.shape[0] for i in hour_gb_18]
plt.plot(x, percent_gb_18,"g")
plt.xticks(rotation = 90)
plt.xlabel("Time interval")
plt.ylabel("Percent of tweets")
plt.title('Percent of tweets in the given time interval GB 2018')
plt.show()

# %% [markdown]
# Graph 2017

# %%
percent_ca_17=[(i*100)//df_ca_17.shape[0] for i in hour_ca_17]
plt.plot(x, percent_ca_17,"r")
plt.xticks(rotation = 90)

plt.xlabel("Time interval")
plt.ylabel("Percent of tweets")
plt.title('Percent of tweets in the given time interval CA 2017')
plt.show()

# %%
percent_gb_17=[(i*100)//df_gb_17.shape[0] for i in hour_gb_17]
plt.plot(x, percent_gb_17,"g")
plt.xticks(rotation = 90)
plt.xlabel("Time interval")
plt.ylabel("Percent of tweets")
plt.title('Percent of tweets in the given time interval GB 2017')
plt.show()
